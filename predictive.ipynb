# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv('nba_games.csv', index_col=0)
df
# Out:
#          mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0     265.0  265.0  43.0  102.0  0.422  19.0  45.0  0.422  17.0  20.0  ...
# 1     265.0  265.0  42.0  103.0  0.408  14.0  40.0  0.350  32.0  38.0  ...
# 2     240.0  240.0  37.0   85.0  0.435  13.0  33.0  0.394  15.0  21.0  ...
# 3     240.0  240.0  42.0   81.0  0.519  11.0  31.0  0.355  17.0  24.0  ...
# 4     240.0  240.0  49.0  105.0  0.467   9.0  30.0  0.300  18.0  22.0  ...
# ...     ...    ...   ...    ...    ...   ...   ...    ...   ...   ...  ...
# 2761  240.0  240.0  41.0   84.0  0.488  11.0  32.0  0.344  20.0  24.0  ...
# 2762  240.0  240.0  44.0   87.0  0.506  15.0  29.0  0.517  16.0  20.0  ...
# 2763  240.0  240.0  41.0   88.0  0.466  17.0  39.0  0.436   4.0  10.0  ...
# 2764  240.0  240.0  39.0   94.0  0.415   8.0  24.0  0.333  22.0  25.0  ...
# 2765  240.0  240.0  44.0   89.0  0.494  14.0  30.0  0.467  28.0  37.0  ...
#
#       tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0             22.2          35.7         158.0         114.0       TOR
# 1             25.0          37.7         146.0         124.0       NOP
# 2             22.2          42.4         203.0         116.0       LAC
# 3             25.0          35.8         300.0         125.0       LAL
# 4            100.0          32.6         208.0         128.0       CHO
# ...            ...           ...           ...           ...       ...
# 2761          50.0          34.3         173.0         128.0       DEN
# 2762          33.3          32.9         148.0         124.0       CHI
# 2763          50.0          38.3         232.0         112.0       BOS
# 2764         100.0          32.6         208.0         114.0       GSW
# 2765         100.0          30.7         221.0         136.0       MIN
#
#       total_opp  home_opp  season        date    won
# 0            13         1    2020  2019-10-22   True
# 1             5         0    2020  2019-10-22  False
# 2           112         1    2020  2019-10-22  False
# 3           102         0    2020  2019-10-22   True
# 4           126         1    2020  2019-10-23  False
# ...         ...       ...     ...         ...    ...
# 2761        117         0    2021  2021-01-25  False
# 2762        103         1    2021  2021-01-25   True
# 2763        119         0    2021  2021-01-25  False
# 2764        130         1    2021  2021-01-25  False
# 2765        108         0    2021  2021-01-25   True
#
# [2766 rows x 150 columns]

# %%
df.season.unique()
# Out:
# array([2020, 2021], dtype=int64)

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#          mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0     265.0  265.0  43.0  102.0  0.422  19.0  45.0  0.422  17.0  20.0  ...
# 1     265.0  265.0  42.0  103.0  0.408  14.0  40.0  0.350  32.0  38.0  ...
# 2     240.0  240.0  37.0   85.0  0.435  13.0  33.0  0.394  15.0  21.0  ...
# 3     240.0  240.0  42.0   81.0  0.519  11.0  31.0  0.355  17.0  24.0  ...
# 4     240.0  240.0  36.0   87.0  0.414   7.0  28.0  0.250  21.0  23.0  ...
# ...     ...    ...   ...    ...    ...   ...   ...    ...   ...   ...  ...
# 2761  240.0  240.0  35.0   70.0  0.500  17.0  38.0  0.447  32.0  38.0  ...
# 2762  240.0  240.0  40.0   94.0  0.426   9.0  28.0  0.321  15.0  20.0  ...
# 2763  240.0  240.0  39.0   94.0  0.415   8.0  24.0  0.333  22.0  25.0  ...
# 2764  240.0  240.0  31.0   84.0  0.369  11.0  43.0  0.256  12.0  17.0  ...
# 2765  240.0  240.0  44.0   89.0  0.494  14.0  30.0  0.467  28.0  37.0  ...
#
#       tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0             22.2          35.7         158.0         114.0       TOR
# 1             25.0          37.7         146.0         124.0       NOP
# 2             22.2          42.4         203.0         116.0       LAC
# 3             25.0          35.8         300.0         125.0       LAL
# 4             30.4          33.9         158.0         109.0       DEN
# ...            ...           ...           ...           ...       ...
# 2761          16.2          35.6         223.0         139.0       PHI
# 2762          43.6          30.3         180.0         121.0       DET
# 2763         100.0          32.6         208.0         114.0       GSW
# 2764          19.7          30.8         153.0          99.0       BRK
# 2765         100.0          30.7         221.0         136.0       MIN
#
#       total_opp  home_opp  season        date    won
# 0            13         1    2020  2019-10-22   True
# 1             5         0    2020  2019-10-22  False
# 2           112         1    2020  2019-10-22  False
# 3           102         0    2020  2019-10-22   True
# 4           108         0    2020  2019-10-23  False
# ...         ...       ...     ...         ...    ...
# 2761        104         0    2021  2021-01-25   True
# 2762        119         1    2021  2021-01-25  False
# 2763        130         1    2021  2021-01-25  False
# 2764         98         1    2021  2021-01-25  False
# 2765        108         0    2021  2021-01-25   True
#
# [2766 rows x 150 columns]

# %%
del df["mp.1"]
del df["mp_opp.1"]
del df["index_opp"]

# %%
df
# Out:
#          mp    fg    fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0     265.0  43.0  102.0  0.422  19.0  45.0  0.422  17.0  20.0  0.850  ...
# 1     265.0  42.0  103.0  0.408  14.0  40.0  0.350  32.0  38.0  0.842  ...
# 2     240.0  37.0   85.0  0.435  13.0  33.0  0.394  15.0  21.0  0.714  ...
# 3     240.0  42.0   81.0  0.519  11.0  31.0  0.355  17.0  24.0  0.708  ...
# 4     240.0  36.0   87.0  0.414   7.0  28.0  0.250  21.0  23.0  0.913  ...
# ...     ...   ...    ...    ...   ...   ...    ...   ...   ...    ...  ...
# 2761  240.0  35.0   70.0  0.500  17.0  38.0  0.447  32.0  38.0  0.842  ...
# 2762  240.0  40.0   94.0  0.426   9.0  28.0  0.321  15.0  20.0  0.750  ...
# 2763  240.0  39.0   94.0  0.415   8.0  24.0  0.333  22.0  25.0  0.880  ...
# 2764  240.0  31.0   84.0  0.369  11.0  43.0  0.256  12.0  17.0  0.706  ...
# 2765  240.0  44.0   89.0  0.494  14.0  30.0  0.467  28.0  37.0  0.757  ...
#
#       tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0             22.2          35.7         158.0         114.0       TOR
# 1             25.0          37.7         146.0         124.0       NOP
# 2             22.2          42.4         203.0         116.0       LAC
# 3             25.0          35.8         300.0         125.0       LAL
# 4             30.4          33.9         158.0         109.0       DEN
# ...            ...           ...           ...           ...       ...
# 2761          16.2          35.6         223.0         139.0       PHI
# 2762          43.6          30.3         180.0         121.0       DET
# 2763         100.0          32.6         208.0         114.0       GSW
# 2764          19.7          30.8         153.0          99.0       BRK
# 2765         100.0          30.7         221.0         136.0       MIN
#
#       total_opp  home_opp  season        date    won
# 0            13         1    2020  2019-10-22   True
# 1             5         0    2020  2019-10-22  False
# 2           112         1    2020  2019-10-22  False
# 3           102         0    2020  2019-10-22   True
# 4           108         0    2020  2019-10-23  False
# ...         ...       ...     ...         ...    ...
# 2761        104         0    2021  2021-01-25   True
# 2762        119         1    2021  2021-01-25  False
# 2763        130         1    2021  2021-01-25  False
# 2764         98         1    2021  2021-01-25  False
# 2765        108         0    2021  2021-01-25   True
#
# [2766 rows x 147 columns]

# %%
# target indicates if the team lost their next game

def add_target(team):
    team ["target"] = team["won"].shift(-1)
    return team

df = df.groupby("team", group_keys=False).apply(add_target)

# %%
df["target"][pd.isnull(df["target"])]
# Out:
# 2657    NaN
# 2701    NaN
# 2722    NaN
# 2724    NaN
# 2726    NaN
# 2731    NaN
# 2736    NaN
# 2737    NaN
# 2738    NaN
# 2739    NaN
# 2740    NaN
# 2742    NaN
# 2745    NaN
# 2746    NaN
# 2750    NaN
# 2751    NaN
# 2752    NaN
# 2753    NaN
# 2754    NaN
# 2755    NaN
# 2756    NaN
# 2757    NaN
# 2758    NaN
# 2759    NaN
# 2760    NaN
# 2761    NaN
# 2762    NaN
# 2763    NaN
# 2764    NaN
# 2765    NaN
# Name: target, dtype: object

# %%
def true_false_conversion(x):
    if x == True:
        return 1
    elif x == False:
        return 0
    else:
        return 2
df["target"] = df["target"].apply(true_false_conversion)

# %%
df
# Out:
#          mp    fg    fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0     265.0  43.0  102.0  0.422  19.0  45.0  0.422  17.0  20.0  0.850  ...
# 1     265.0  42.0  103.0  0.408  14.0  40.0  0.350  32.0  38.0  0.842  ...
# 2     240.0  37.0   85.0  0.435  13.0  33.0  0.394  15.0  21.0  0.714  ...
# 3     240.0  42.0   81.0  0.519  11.0  31.0  0.355  17.0  24.0  0.708  ...
# 4     240.0  36.0   87.0  0.414   7.0  28.0  0.250  21.0  23.0  0.913  ...
# ...     ...   ...    ...    ...   ...   ...    ...   ...   ...    ...  ...
# 2761  240.0  35.0   70.0  0.500  17.0  38.0  0.447  32.0  38.0  0.842  ...
# 2762  240.0  40.0   94.0  0.426   9.0  28.0  0.321  15.0  20.0  0.750  ...
# 2763  240.0  39.0   94.0  0.415   8.0  24.0  0.333  22.0  25.0  0.880  ...
# 2764  240.0  31.0   84.0  0.369  11.0  43.0  0.256  12.0  17.0  0.706  ...
# 2765  240.0  44.0   89.0  0.494  14.0  30.0  0.467  28.0  37.0  0.757  ...
#
#       usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  home_opp  \
# 0             35.7         158.0         114.0       TOR         13         1
# 1             37.7         146.0         124.0       NOP          5         0
# 2             42.4         203.0         116.0       LAC        112         1
# 3             35.8         300.0         125.0       LAL        102         0
# 4             33.9         158.0         109.0       DEN        108         0
# ...            ...           ...           ...       ...        ...       ...
# 2761          35.6         223.0         139.0       PHI        104         0
# 2762          30.3         180.0         121.0       DET        119         1
# 2763          32.6         208.0         114.0       GSW        130         1
# 2764          30.8         153.0          99.0       BRK         98         1
# 2765          30.7         221.0         136.0       MIN        108         0
#
#       season        date    won  target
# 0       2020  2019-10-22   True       0
# 1       2020  2019-10-22  False       0
# 2       2020  2019-10-22  False       1
# 3       2020  2019-10-22   True       1
# 4       2020  2019-10-23  False       1
# ...      ...         ...    ...     ...
# 2761    2021  2021-01-25   True       2
# 2762    2021  2021-01-25  False       2
# 2763    2021  2021-01-25  False       2
# 2764    2021  2021-01-25  False       2
# 2765    2021  2021-01-25   True       2
#
# [2766 rows x 148 columns]

# %%
df["won"].value_counts()
# Out:
# False    1393
# True     1373
# Name: won, dtype: int64

# %%
df["target"].value_counts()
# Out:
# 0    1378
# 1    1358
# 2      30
# Name: target, dtype: int64

# %%
# Check how many columns have null values
nulls = pd.isnull(df)

# %%
nulls = nulls.sum()

# %%
nulls = nulls[nulls > 0]

# %%
# Delete previous cell columns
valid_columns = df.columns[~df.columns.isin(nulls.index)]

# %%
valid_columns
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=142)

# %%
df = df[valid_columns].copy()

# %%
# Feature Selection
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha=1)
split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr, n_features_to_select=30, direction="forward", cv=split)

# %%
removed_columns= ["season", "date", "won", "target", "team", "team_opp"]

# %%
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns] )

# %%
sfs.fit(df[selected_columns], df["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['mp',
#  'fg%',
#  'fta',
#  'ast',
#  'pts',
#  'orb%',
#  'usg%',
#  'ortg',
#  'fga_max',
#  'fta_max',
#  'ast_max',
#  'blk_max',
#  'tov_max',
#  '+/-_max',
#  'drb%_max',
#  'tov%_max',
#  'total',
#  'mp_opp',
#  'fta_opp',
#  'pf_opp',
#  'drb%_opp',
#  'usg%_opp',
#  'drtg_opp',
#  'ft%_max_opp',
#  'orb_max_opp',
#  'tov_max_opp',
#  '+/-_max_opp',
#  'orb%_max_opp',
#  'trb%_max_opp',
#  'drtg_max_opp']

# %%
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []
    
    seasons = sorted(data["season"].unique())
    
    for i in range(start, len(seasons), step):
        season = seasons[i]
        
        # All data used to predict current season
        train = data[data["season"] < season]
        
        # Used to generate predictions
        test = data[data["season"] == season]
        
        # Fit model
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "predictions"]
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [227], in <cell line: 1>()
# ----> 1 all_predictions
#
# NameError: name 'all_predictions' is not defined

# %%
predictions = backtest(df, rr, predictors)
